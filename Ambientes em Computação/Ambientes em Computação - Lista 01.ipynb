# %%
linguagem = "python" #Define a string "linguagem" e atribui o valor "python" a ela
print(linguagem) #Imprime na tela o valor da string
# Out:
# python

# %%
a = 1500
b = 335
print(a+b)##Define e atribui valor às variáveis 'a' e 'b'
print(a*b)##Imprime na tela o resultado das operações de soma, multiplicação e subtração das variáveis
print(a-b)
# Out:
# 1835
# 502500
# 1165

# %%
a = "Marrie"  #Define as strings 'a' , 'b' e 'c' e imprime na tela o resultado da concatenação dessas strings
b = " Currie "
c = "!!! "
print(a + b + c)
# Out:
# Marrie Currie !!!

# %%
print(2 + 3 == 5) #Imprime na tela o resultado da expressão booleana entre parenteses
# Out:
# True

# %%
print(5 + 9 = 13)#É gerado um erro pois ele tenta fazer uma atribuição (13) a um valor de soma (5+9) e não a uma variável
# Out:
#   File "<ipython-input-5-1370359d575c>", line 1
#     print(5 + 9 = 13)
#          ^
# SyntaxError: keyword can't be an expression

# %%
pi = 3.1415 # Valor do número pi
print(pi) ##Imprime na tela o valor atribuido à variável 'pi'
# Out:
# 3.1415

# %%
pi = 3.1415 # Valor do número pi
 print(pi) # Com um "tab" antes do print(pi)


###É gerado um erro pois o "tab" antes do print(pi) é traduzido como uma indentação que não foi iniciada por nenhuma condicional (if , for , while , etc)
# Out:
#   File "<ipython-input-8-7ccc026aaabf>", line 2
#     print(pi) # Com um "tab" antes do print(pi)
#     ^
# IndentationError: unexpected indent
